# %%
import pandas as pd
import os
import datetime

# %%
file1 = "Resources/JC-202201-citibike-tripdata.csv"
file2 = "Resources/JC-202202-citibike-tripdata.csv"
file3 = "Resources/JC-202203-citibike-tripdata.csv"
file4 = "Resources/JC-202204-citibike-tripdata.csv"
file5 = "Resources/JC-202205-citibike-tripdata.csv"
file6 = "Resources/JC-202206-citibike-tripdata.csv"

file_list = [file1,file2,file3,file4,file5, file6]
df_list = []

for file in file_list:
    df = pd.read_csv(file, encoding='utf-8', encoding_errors='replace')
    df_list.append(df)

print(df_list)
# Out:
# [                ride_id  rideable_type           started_at  \
# 0      CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1      BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2      7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3      6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4      E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                 ...            ...                  ...
# 26757  439B3B4ADB37F46F  electric_bike  2022-01-03 16:07:27
# 26758  11C0F2F85CBF7623  electric_bike  2022-01-22 20:02:58
# 26759  E77502BB6C6A7ADD   classic_bike  2022-01-26 12:35:21
# 26760  75C57C18EE9980EA   classic_bike  2022-01-28 12:56:34
# 26761  2EC5621EF3DCB2FA   classic_bike  2022-01-31 12:45:16
#
#                   ended_at    start_station_name start_station_id  \
# 0      2022-01-26 18:51:53  12 St & Sinatra Dr N            HB201
# 1      2022-01-28 13:20:23      Essex Light Rail            JC038
# ...

# %%
if os.path.exists(file6):
    print("file exists")
else:
    print("cant find it")
# Out:
# file exists

# %%
df_merged = pd.concat(df_list)
df_merged.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  CA5837152804D4B5  electric_bike  2022-01-26 18:50:39  2022-01-26 18:51:53
# 1  BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07  2022-01-28 13:20:23
# 2  7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13  2022-01-10 20:00:37
# 3  6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57  2022-01-26 07:55:22
# 4  E24954255BBDE32D  electric_bike  2022-01-13 18:44:46  2022-01-13 18:45:43
#
#      start_station_name start_station_id      end_station_name end_station_id  \
# 0  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 1      Essex Light Rail            JC038      Essex Light Rail          JC038
# 2      Essex Light Rail            JC038      Essex Light Rail          JC038
# 3  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 4  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
#
# ...

# %%
df_merged.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df_merged.isnull().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name      1231
# end_station_id        1231
# start_lat                0
# start_lng                0
# end_lat                923
# end_lng                923
# member_casual            0
# dtype: int64

# %%
df_merged.shape
# Out:
# (356653, 13)

# %%
df_merged[['started_at', 'ended_at']] = df_merged[['started_at', 'ended_at']].apply(pd.to_datetime)
df_merged.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356653 entries, 0 to 103298
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             356653 non-null  object
#  1   rideable_type       356653 non-null  object
#  2   started_at          356653 non-null  datetime64[ns]
#  3   ended_at            356653 non-null  datetime64[ns]
#  4   start_station_name  356653 non-null  object
#  5   start_station_id    356653 non-null  object
#  6   end_station_name    355422 non-null  object
#  7   end_station_id      355422 non-null  object
#  8   start_lat           356653 non-null  float64
#  9   start_lng           356653 non-null  float64
#  10  end_lat             355730 non-null  float64
#  11  end_lng             355730 non-null  float64
#  12  member_casual       356653 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 38.1+ MB

# %%
df_merged.tail()
# Out:
#                  ride_id  rideable_type          started_at  \
# 103294  25AD34565A260732   classic_bike 2022-06-17 16:03:36
# 103295  8A4181FCE9439036   classic_bike 2022-06-25 14:14:26
# 103296  28C8501BCB596743  electric_bike 2022-06-04 08:57:04
# 103297  D28575BBFF3A0B57   classic_bike 2022-06-17 06:11:05
# 103298  A914FEF9390C201C  electric_bike 2022-06-02 18:15:17
#
#                   ended_at                            start_station_name  \
# 103294 2022-06-17 16:33:48  South Waterfront Walkway - Sinatra Dr & 1 St
# 103295 2022-06-25 14:19:40  South Waterfront Walkway - Sinatra Dr & 1 St
# 103296 2022-06-04 09:15:33                               Jersey & 6th St
# 103297 2022-06-17 06:21:37  South Waterfront Walkway - Sinatra Dr & 1 St
# 103298 2022-06-02 18:20:22  South Waterfront Walkway - Sinatra Dr & 1 St
#
#        start_station_id       end_station_name end_station_id  start_lat  \
# 103294            HB103  11 St & Washington St          HB502  40.736982
# ...

# %%
df_merged['ride_id'] = df_merged['ride_id'].astype('string')
df_merged.dtypes
# Out:
# ride_id                       string
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
df_merged[['rideable_type', 'start_station_name', 'end_station_name', 'member_casual']] = df_merged[['rideable_type', 'start_station_name', 'end_station_name', 'member_casual']].astype('string')
df_merged.dtypes
# Out:
# ride_id                       string
# rideable_type                 string
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            string
# start_station_id              object
# end_station_name              string
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 string
# dtype: object

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  CA5837152804D4B5  electric_bike 2022-01-26 18:50:39 2022-01-26 18:51:53
# 1  BA06A5E45B6601D2   classic_bike 2022-01-28 13:14:07 2022-01-28 13:20:23
# 2  7B6827D7B9508D93   classic_bike 2022-01-10 19:55:13 2022-01-10 20:00:37
# 3  6E5864EA6FCEC90D  electric_bike 2022-01-26 07:54:57 2022-01-26 07:55:22
# 4  E24954255BBDE32D  electric_bike 2022-01-13 18:44:46 2022-01-13 18:45:43
#
#      start_station_name start_station_id      end_station_name end_station_id  \
# 0  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 1      Essex Light Rail            JC038      Essex Light Rail          JC038
# 2      Essex Light Rail            JC038      Essex Light Rail          JC038
# 3  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
# 4  12 St & Sinatra Dr N            HB201  12 St & Sinatra Dr N          HB201
#
# ...

# %%
df_merged.tail(5)
# Out:
#                  ride_id  rideable_type          started_at  \
# 103294  25AD34565A260732   classic_bike 2022-06-17 16:03:36
# 103295  8A4181FCE9439036   classic_bike 2022-06-25 14:14:26
# 103296  28C8501BCB596743  electric_bike 2022-06-04 08:57:04
# 103297  D28575BBFF3A0B57   classic_bike 2022-06-17 06:11:05
# 103298  A914FEF9390C201C  electric_bike 2022-06-02 18:15:17
#
#                   ended_at                            start_station_name  \
# 103294 2022-06-17 16:33:48  South Waterfront Walkway - Sinatra Dr & 1 St
# 103295 2022-06-25 14:19:40  South Waterfront Walkway - Sinatra Dr & 1 St
# 103296 2022-06-04 09:15:33                               Jersey & 6th St
# 103297 2022-06-17 06:21:37  South Waterfront Walkway - Sinatra Dr & 1 St
# 103298 2022-06-02 18:20:22  South Waterfront Walkway - Sinatra Dr & 1 St
#
#        start_station_id       end_station_name end_station_id  start_lat  \
# 103294            HB103  11 St & Washington St          HB502  40.736982
# ...

# %%
df_merged.shape
# Out:
# (356653, 13)

# %%
df.index[-1]
# Out:
# 103298

# %%
num_rows = df.count()
num_rows
# Out:
# ride_id               103299
# rideable_type         103299
# started_at            103299
# ended_at              103299
# start_station_name    103299
# start_station_id      103299
# end_station_name      102985
# end_station_id        102985
# start_lat             103299
# start_lng             103299
# end_lat               103004
# end_lng               103004
# member_casual         103299
# dtype: int64

# %%
df_merged = df_merged.drop_duplicates()
df_merged.shape
# Out:
# (356653, 13)

# %%
num_rows
# Out:
# ride_id               103299
# rideable_type         103299
# started_at            103299
# ended_at              103299
# start_station_name    103299
# start_station_id      103299
# end_station_name      102985
# end_station_id        102985
# start_lat             103299
# start_lng             103299
# end_lat               103004
# end_lng               103004
# member_casual         103299
# dtype: int64

# %%
df_merged.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name      1231
# end_station_id        1231
# start_lat                0
# start_lng                0
# end_lat                923
# end_lng                923
# member_casual            0
# dtype: int64

# %%
df_merged.iloc[40000:50001].head()
# Out:
#                 ride_id  rideable_type          started_at  \
# 13238  810134E785CC4C47   classic_bike 2022-02-17 18:07:12
# 13239  A93DBDFF6F0AD570   classic_bike 2022-02-16 21:20:00
# 13240  372ECD57A0BE6067  electric_bike 2022-02-15 19:39:23
# 13241  16C5D300AD089C3A   classic_bike 2022-02-26 21:25:30
# 13242  5CA2E46CA2579575  electric_bike 2022-02-02 20:41:17
#
#                  ended_at                       start_station_name  \
# 13238 2022-02-17 18:14:44  Hoboken Terminal - River St & Hudson Pl
# 13239 2022-02-16 21:26:21  Hoboken Terminal - River St & Hudson Pl
# 13240 2022-02-15 19:44:51  Hoboken Terminal - River St & Hudson Pl
# 13241 2022-02-26 21:31:38  Hoboken Terminal - River St & Hudson Pl
# 13242 2022-02-02 20:46:59  Hoboken Terminal - River St & Hudson Pl
#
#       start_station_id       end_station_name end_station_id  start_lat  \
# 13238            HB102   8 St & Washington St          HB603  40.736068
# ...

# %%
df_merged['rideable_type'] = df_merged['rideable_type'].str.replace('_',' ')
df_merged.iloc[40000:50001].head()
# Out:
#                 ride_id  rideable_type          started_at  \
# 13238  810134E785CC4C47   classic bike 2022-02-17 18:07:12
# 13239  A93DBDFF6F0AD570   classic bike 2022-02-16 21:20:00
# 13240  372ECD57A0BE6067  electric bike 2022-02-15 19:39:23
# 13241  16C5D300AD089C3A   classic bike 2022-02-26 21:25:30
# 13242  5CA2E46CA2579575  electric bike 2022-02-02 20:41:17
#
#                  ended_at                       start_station_name  \
# 13238 2022-02-17 18:14:44  Hoboken Terminal - River St & Hudson Pl
# 13239 2022-02-16 21:26:21  Hoboken Terminal - River St & Hudson Pl
# 13240 2022-02-15 19:44:51  Hoboken Terminal - River St & Hudson Pl
# 13241 2022-02-26 21:31:38  Hoboken Terminal - River St & Hudson Pl
# 13242 2022-02-02 20:46:59  Hoboken Terminal - River St & Hudson Pl
#
#       start_station_id       end_station_name end_station_id  start_lat  \
# 13238            HB102   8 St & Washington St          HB603  40.736068
# ...

# %%
df_merged.rename(columns={col:col.replace("_"," ") for col in df_merged.columns if "_" in col }, inplace=True)
df_merged.iloc[40000:50001].head()
# Out:
#                 ride id  rideable type          started at  \
# 13238  810134E785CC4C47   classic bike 2022-02-17 18:07:12
# 13239  A93DBDFF6F0AD570   classic bike 2022-02-16 21:20:00
# 13240  372ECD57A0BE6067  electric bike 2022-02-15 19:39:23
# 13241  16C5D300AD089C3A   classic bike 2022-02-26 21:25:30
# 13242  5CA2E46CA2579575  electric bike 2022-02-02 20:41:17
#
#                  ended at                       start station name  \
# 13238 2022-02-17 18:14:44  Hoboken Terminal - River St & Hudson Pl
# 13239 2022-02-16 21:26:21  Hoboken Terminal - River St & Hudson Pl
